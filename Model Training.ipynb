# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratye/Drone-Surveillance-Contest/blob/main/Model%20Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Initialisation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Thu Aug  5 17:05:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Building Darknet for YoloV4

# %%
# %cd /content/drive/MyDrive/Colab
# !git clone https://github.com/roboflow-ai/darknet.git

# %%
# %cd /content/drive/MyDrive/Colab/darknet
# !mkdir build-release
# %cd /content/drive/MyDrive/Colab/darknet/build-release
# !cmake ..
# !make
# !make install

# %%
# %cd /content/drive/MyDrive/Colab/darknet/build/darknet/x64
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %%
# %cd /content/drive/MyDrive/Colab/darknet/build/darknet/x64/data
# !mkdir obj
# %cd /content/drive/MyDrive/Colab/darknet/build/darknet/x64/data/obj
# !curl -L "https://app.roboflow.com/ds/6MpiY3Mbh1?key=x5ComyKnvX" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %% [markdown]
# ## Start Training

# %%
# %cd /content/drive/MyDrive/Colab/darknet
# Out:
# /content/drive/MyDrive/Colab/darknet

# %%
# !./darknet detector train build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4-custom-detector.cfg build/darknet/x64/yolov4.conv.137  -dont_show -mjpeg_port 8090 -map
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  Prepare additional network for mAP calculation...
#  compute_capability = 750, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %% [markdown]
# ## Continueing Training With Saved Weights

# %%
# !chmod +x /content/drive/MyDrive/Colab/darknet/darknet

# %%
# !./darknet detector train build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4-custom-detector.cfg build/darknet/x64/backup/yolov4-custom-detector_last.weights  -dont_show -mjpeg_port 8090 -map
# Out:
# Streaming output truncated to the last 5000 lines.
#  (next mAP calculation at 1000 iterations)
#  995: 7.171749, 10.672132 avg loss, 0.000980 rate, 14.335322 seconds, 63680 images, 12.300839 hours left
#  MJPEG-stream sent.
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations)
#  996: 9.401261, 10.545046 avg loss, 0.000984 rate, 15.693376 seconds, 63744 images, 12.297491 hours left
#  MJPEG-stream sent.
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations)
#  997: 11.771694, 10.667710 avg loss, 0.000988 rate, 16.795359 seconds, 63808 images, 12.305469 hours left
#  MJPEG-stream sent.
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 1000 iterations)
#  998: 9.723391, 10.573278 avg loss, 0.000992 rate, 16.254361 seconds, 63872 images, 12.322516 hours left
#  MJPEG-stream sent.
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 1000 iterations)
# ...

# %% [markdown]
# # Reffer to make the train.txt and test.txt

# %%
import os


for i in os.listdir('/content/drive/MyDrive/Colab/darknet/build/darknet/x64/data/obj'):
  if i=='README.roboflow.txt':
    continue
  else:
    x = os.path.join('/content/drive/MyDrive/Colab/darknet/build/darknet/x64/data/obj',i)
    a = os.path.join('build/darknet/x64/data/obj', i)

    for img in os.listdir(x):
      if img=='_darknet.labels' or img.endswith('txt')==True:
        continue
      else:
        print(os.path.join(a, img))

        #/content/darknet/cfg/yolov4-custom-detector.cfg
